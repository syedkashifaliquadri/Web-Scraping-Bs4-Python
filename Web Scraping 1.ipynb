# %%
import requests

# %%
import bs4

# %%
res = requests.get('https://courses.learncodeonline.in')

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!doctype html><html><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"><title>Learn code online | A complete programming video tutorial site</title><meta name="description" content="Learncodeonline.in is a platform to learn about programming and make projects with that knowledge. Access high quality videos at reasonable price."><meta name="twitter:card" content="summary" /><meta name="twitter:title" property="og:title" itemprop="title name" content="" /><meta property="og:title" itemprop="title name" content="Learn code online | A complete programming video tutorial site" /><meta property="og:url" content="courses.learncodeonline.in" /><meta property="og:type" content="website" /><meta name="og:description" itemprop="description" content="Learncodeonline.in is a platform to learn about programming and make projects with that knowledge. Access high qua
# ...

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
ti = soup.select('title')

# %%
ti
# Out:
# [<title>Learn code online | A complete programming video tutorial site</title>]

# %%
ti[0]
# Out:
# <title>Learn code online | A complete programming video tutorial site</title>

# %%
ti[0].getText()
# Out:
# 'Learn code online | A complete programming video tutorial site'

# %%
for link in soup.find_all('a', href=True):
    print(link['href'])
# Out:
# https://courses.learncodeonline.in
# #Sec-id-10-4
# #Sec-id-9-6
# #Sec-id-8-11
# https://play.google.com/store/apps/details?id=in.learncodeonline.lco&hl=en
# https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewSoftware?id=1273049320&mt=8
# /auth/google_oauth2
# /auth/facebook
# /passwords/new
# /signup
# /auth/facebook
# /auth/google_oauth2
# javascript:void(0);
# javascript:void(0);
# /learn
# /learn
# https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewSoftware?id=1273049320&mt=8
# https://play.google.com/store/apps/details?id=in.learncodeonline.lco
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# https://fb.com/hiteshchoudharypage
# https://youtube.com/hiteshitube
# https://instagram.com/hiteshchoudharyofficial
# https://courses.learncodeonline.in
# https://fb.com/HiteshChoudharyPage
# https://learncodeonline.in/contact/
# https://youtube.com/hiteshitube
# https://play.google.com/store/apps/details?id=in.learncodeonline.lco&hl=en
# ...
